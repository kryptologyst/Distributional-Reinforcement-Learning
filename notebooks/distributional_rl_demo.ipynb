# %% [markdown]
# # Distributional Reinforcement Learning Demo
#
# This notebook demonstrates the distributional RL implementation with interactive examples.

# %%
# Import required libraries
import sys
import os
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm

from envs import make_env, MiniGridWorld
from agents import C51Agent
from utils import MetricsLogger, Visualizer, set_seed
from utils.config import load_config

# Set up plotting
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (10, 6)
